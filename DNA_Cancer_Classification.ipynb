# %%
import sys

print("Python version:", sys.version)
print("Python location:", sys.executable)
# Out:
# Python version: 3.11.15 | packaged by Anaconda, Inc. | (main, Mar 11 2026, 17:12:15) [MSC v.1942 64 bit (AMD64)]
# Python location: c:\Users\Shreya G\miniconda\envs\ai\python.exe

# %%
# %pip install pandas numpy scikit-learn matplotlib seaborn joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import sklearn

import matplotlib.pyplot as plt
import seaborn as sns
import joblib

print("All libraries imported successfully!")
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
print("Scikit-learn version:", sklearn.__version__)
# Out:
# All libraries imported successfully!
# Pandas version: 3.0.5
# NumPy version: 2.4.5
# Scikit-learn version: 1.9.0

# %%
print("Pandas is working correctly!")
print("pd type:", type(pd))
# Out:
# Pandas is working correctly!
# pd type: <class 'module'>

# %%
df = pd.read_csv("../Data/DNA_Dataset_Normalized.csv")

print("Dataset loaded successfully!")
print("Rows and columns:", df.shape)
# Out:
# Dataset loaded successfully!
# Rows and columns: (390, 45)

# %%
df.head()
# Out:
#      gene_1    gene_2    gene_3     gene_4    gene_6    gene_7  gene_10  \
# 0  2.325242  3.247092  8.174007  10.065053  7.487446  0.000000      0.0
# 1  3.446190  3.620962  7.171917   9.796559  8.175245  1.972509      0.0
# 2  2.554196  1.296134  8.770277  10.462901  8.013993  0.000000      0.0
# 3  3.667699  3.083179  7.997292   9.516886  7.925424  0.732486      0.0
# 4  3.821935  3.717605  7.593100  10.205964  7.613185  0.000000      0.0
#
#     gene_11   gene_12  gene_13  ...  gene_41   gene_42   gene_43   gene_44  \
# 0  0.000000  2.759582      0.0  ...      0.0  0.000000  0.566572  2.759582
# 1  1.972509  2.218967      0.0  ...      0.0  0.000000  0.000000  0.000000
# 2  0.736562  3.543446      0.0  ...      0.0  0.414785  0.000000  6.290605
# 3  0.000000  3.762157      0.0  ...      0.0  0.000000  0.000000  0.000000
# 4  0.000000  1.982364      0.0  ...      0.0  0.000000  0.000000  2.261441
#
#     gene_45    gene_46    gene_47    gene_48   gene_49  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 45 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gene_1   390 non-null    float64
#  1   gene_2   390 non-null    float64
#  2   gene_3   390 non-null    float64
#  3   gene_4   390 non-null    float64
#  4   gene_6   390 non-null    float64
#  5   gene_7   390 non-null    float64
#  6   gene_10  390 non-null    float64
#  7   gene_11  390 non-null    float64
#  8   gene_12  390 non-null    float64
#  9   gene_13  390 non-null    float64
#  10  gene_14  390 non-null    float64
#  11  gene_17  390 non-null    float64
#  12  gene_18  390 non-null    float64
#  13  gene_19  390 non-null    float64
#  14  gene_20  390 non-null    float64
#  15  gene_21  390 non-null    float64
#  16  gene_22  390 non-null    float64
#  17  gene_23  390 non-null    int64
#  18  gene_24  390 non-null    float64
#  19  gene_25  390 non-null    float64
# ...

# %%
print("Number of columns:", len(df.columns))
print("\nColumn names:")
print(df.columns.tolist())
# Out:
# Number of columns: 45
#
# Column names:
# ['gene_1', 'gene_2', 'gene_3', 'gene_4', 'gene_6', 'gene_7', 'gene_10', 'gene_11', 'gene_12', 'gene_13', 'gene_14', 'gene_17', 'gene_18', 'gene_19', 'gene_20', 'gene_21', 'gene_22', 'gene_23', 'gene_24', 'gene_25', 'gene_26', 'gene_27', 'gene_28', 'gene_29', 'gene_30', 'gene_31', 'gene_32', 'gene_33', 'gene_34', 'gene_35', 'gene_36', 'gene_37', 'gene_38', 'gene_39', 'gene_40', 'gene_41', 'gene_42', 'gene_43', 'gene_44', 'gene_45', 'gene_46', 'gene_47', 'gene_48', 'gene_49', 'Class']

# %%
missing_values = df.isnull().sum()

print("Missing values in each column:")
print(missing_values)

print("\nTotal missing values:", df.isnull().sum().sum())
# Out:
# Missing values in each column:
# gene_1     0
# gene_2     0
# gene_3     0
# gene_4     0
# gene_6     0
# gene_7     0
# gene_10    0
# gene_11    0
# gene_12    0
# gene_13    0
# gene_14    0
# gene_17    0
# gene_18    0
# gene_19    0
# gene_20    0
# gene_21    0
# gene_22    0
# gene_23    0
# gene_24    0
# gene_25    0
# gene_26    0
# gene_27    0
# gene_28    0
# gene_29    0
# gene_30    0
# gene_31    0
# gene_32    0
# gene_33    0
# gene_34    0
# gene_35    0
# gene_36    0
# gene_37    0
# gene_38    0
# gene_39    0
# gene_40    0
# gene_41    0
# gene_42    0
# gene_43    0
# gene_44    0
# gene_45    0
# gene_46    0
# gene_47    0
# gene_48    0
# gene_49    0
# Class      0
# dtype: int64
#
# Total missing values: 0

# %%
df.describe()
# Out:
#            gene_1      gene_2      gene_3      gene_4      gene_6      gene_7  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     3.025948    3.192807    6.834967    9.785579    7.330231    0.482853
# std      1.246116    1.049015    0.737371    0.497189    1.032067    0.513565
# min      0.000000    0.000000    5.009284    8.435999    4.534466    0.000000
# 25%      2.341329    2.490260    6.347902    9.444469    6.615592    0.000000
# 50%      3.165172    3.216300    6.735995    9.761957    7.433040    0.442652
# 75%      3.857806    3.836318    7.161614   10.125391    7.995617    0.755208
# max      6.237034    5.848044   10.129528   11.269372   10.219132    2.779008
#
#           gene_10     gene_11     gene_12     gene_13  ...     gene_41  \
# count  390.000000  390.000000  390.000000  390.000000  ...  390.000000
# mean     0.663875    0.904628    2.654270    0.233360  ...    0.093538
# ...

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
print(df.dtypes)
# Out:
# gene_1     float64
# gene_2     float64
# gene_3     float64
# gene_4     float64
# gene_6     float64
# gene_7     float64
# gene_10    float64
# gene_11    float64
# gene_12    float64
# gene_13    float64
# gene_14    float64
# gene_17    float64
# gene_18    float64
# gene_19    float64
# gene_20    float64
# gene_21    float64
# gene_22    float64
# gene_23      int64
# gene_24    float64
# gene_25    float64
# gene_26    float64
# gene_27    float64
# gene_28    float64
# gene_29    float64
# gene_30    float64
# gene_31    float64
# gene_32    float64
# gene_33    float64
# gene_34    float64
# gene_35    float64
# gene_36    float64
# gene_37    float64
# gene_38    float64
# gene_39    float64
# gene_40    float64
# gene_41    float64
# gene_42    float64
# gene_43    float64
# gene_44    float64
# gene_45    float64
# gene_46    float64
# gene_47    float64
# gene_48    float64
# gene_49    float64
# Class        int64
# dtype: object

# %%
print("Class values:")
print(df["Class"].unique())

print("\nNumber of samples in each class:")
print(df["Class"].value_counts())
# Out:
# Class values:
# [1 2 3 4 5]
#
# Number of samples in each class:
# Class
# 1    78
# 2    78
# 3    78
# 4    78
# 5    78
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))

sns.countplot(x="Class", data=df)

plt.title("Distribution of Cancer Classes")
plt.xlabel("Class")
plt.ylabel("Number of Samples")
plt.show()

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

print("Feature matrix shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Feature matrix shape: (390, 44)
# Target shape: (390,)

# %%
print("Feature data types:")
print(X.dtypes.value_counts())

print("\nFirst 5 feature rows:")
display(X.head())
# Out:
# Feature data types:
# float64    43
# int64       1
# Name: count, dtype: int64
#
# First 5 feature rows:
#      gene_1    gene_2    gene_3     gene_4    gene_6    gene_7  gene_10  \
# 0  2.325242  3.247092  8.174007  10.065053  7.487446  0.000000      0.0
# 1  3.446190  3.620962  7.171917   9.796559  8.175245  1.972509      0.0
# 2  2.554196  1.296134  8.770277  10.462901  8.013993  0.000000      0.0
# 3  3.667699  3.083179  7.997292   9.516886  7.925424  0.732486      0.0
# 4  3.821935  3.717605  7.593100  10.205964  7.613185  0.000000      0.0
#
#     gene_11   gene_12  gene_13  ...    gene_40  gene_41   gene_42   gene_43  \
# 0  0.000000  2.759582      0.0  ...  10.086269      0.0  0.000000  0.566572
# 1  1.972509  2.218967      0.0  ...  10.499746      0.0  0.000000  0.000000
# 2  0.736562  3.543446      0.0  ...  10.060642      0.0  0.414785  0.000000
# 3  0.000000  3.762157      0.0  ...   9.675841      0.0  0.000000  0.000000
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training features:", X_train.shape)
print("Testing features:", X_test.shape)
print("Training labels:", y_train.shape)
print("Testing labels:", y_test.shape)
# Out:
# Training features: (312, 44)
# Testing features: (78, 44)
# Training labels: (312,)
# Testing labels: (78,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Original training shape:", X_train.shape)
print("Scaled training shape:", X_train_scaled.shape)

print("\nScaling completed successfully!")
# Out:
# Original training shape: (312, 44)
# Scaled training shape: (312, 44)
#
# Scaling completed successfully!

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    max_iter=2000,
    random_state=42
)

model.fit(X_train_scaled, y_train)

print("Logistic Regression model trained successfully!")
# Out:
# Logistic Regression model trained successfully!

# %%
y_pred = model.predict(X_test_scaled)

print("Predictions generated successfully!")
print("Number of predictions:", len(y_pred))

print("\nFirst 10 predictions:")
print(y_pred[:10])
# Out:
# Predictions generated successfully!
# Number of predictions: 78
#
# First 10 predictions:
# [1 3 4 5 2 4 4 3 2 4]

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Model Accuracy: 92.31%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.94      0.94      0.94        16
#            2       1.00      0.93      0.97        15
#            3       1.00      1.00      1.00        16
#            4       0.87      0.81      0.84        16
#            5       0.82      0.93      0.88        15
#
#     accuracy                           0.92        78
#    macro avg       0.93      0.92      0.92        78
# weighted avg       0.93      0.92      0.92        78

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[15  0  0  1  0]
#  [ 0 14  0  0  1]
#  [ 0  0 16  0  0]
#  [ 1  0  0 13  2]
#  [ 0  0  0  1 14]]

# %%
plt.figure(figsize=(7, 6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=[1, 2, 3, 4, 5],
    yticklabels=[1, 2, 3, 4, 5]
)

plt.title("Confusion Matrix - Logistic Regression")
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_auc_score

y_test_proba = model.predict_proba(X_test_scaled)

roc_auc = roc_auc_score(
    y_test,
    y_test_proba,
    multi_class="ovr",
    average="macro"
)

print("Macro ROC-AUC:", round(roc_auc, 4))
# Out:
# Macro ROC-AUC: 0.9933

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

classes = np.array(sorted(y.unique()))

y_test_bin = label_binarize(y_test, classes=classes)

plt.figure(figsize=(8, 6))

for i, class_label in enumerate(classes):
    fpr, tpr, _ = roc_curve(
        y_test_bin[:, i],
        y_test_proba[:, i]
    )

    roc_auc_class = auc(fpr, tpr)

    plt.plot(
        fpr,
        tpr,
        label=f"Class {class_label} (AUC = {roc_auc_class:.2f})"
    )

plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves - Multiclass Logistic Regression")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
feature_names = X.columns

coefficients = pd.DataFrame(
    model.coef_,
    columns=feature_names,
    index=[f"Class {c}" for c in model.classes_]
)

print("Logistic Regression coefficients:")
display(coefficients)
# Out:
# Logistic Regression coefficients:
#            gene_1    gene_2    gene_3    gene_4    gene_6    gene_7   gene_10  \
# Class 1  0.036708 -0.093446  0.562371 -0.203554 -0.094790  0.049073  0.021734
# Class 2  0.098328  0.398200 -0.189013 -0.083005  0.070078 -0.184823 -0.036795
# Class 3 -0.271237 -0.082897 -0.422009  0.038414 -0.196330  0.255015 -0.105124
# Class 4  0.109110  0.315937  0.092819  0.250510 -0.362066  0.070910  0.190536
# Class 5  0.027090 -0.537793 -0.044169 -0.002365  0.583108 -0.190175 -0.070350
#
#           gene_11   gene_12   gene_13  ...   gene_40   gene_41   gene_42  \
# Class 1 -0.052368 -0.018613 -0.120878  ...  0.081750  0.082529  0.114361
# Class 2 -0.200023  0.100404  0.140914  ... -0.005195 -0.115836 -0.080311
# Class 3 -0.228533 -0.045037 -0.077424  ... -0.375114  0.018036 -0.033211
# Class 4  0.112251  0.255900  0.004163  ... -0.206493 -0.031004 -0.041640
# Class 5  0.368673 -0.292654  0.053225  ...  0.505051  0.046275  0.040801
#
# ...

# %%
gene_importance = pd.DataFrame({
    "Gene": feature_names,
    "Importance": np.mean(np.abs(model.coef_), axis=0)
})

gene_importance = gene_importance.sort_values(
    "Importance",
    ascending=False
)

print("Top 10 most influential genes:")
display(gene_importance.head(10))
# Out:
# Top 10 most influential genes:
#        Gene  Importance
# 38  gene_44    0.612356
# 22  gene_28    0.525900
# 24  gene_30    0.502846
# 20  gene_26    0.478427
# 23  gene_29    0.435126
# 27  gene_33    0.385657
# 40  gene_46    0.379379
# 41  gene_47    0.373163
# 39  gene_45    0.364444
# 25  gene_31    0.351454

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight="balanced"
)

rf_model.fit(X_train, y_train)

print("Random Forest model trained successfully!")
# Out:
# Random Forest model trained successfully!

# %%
rf_pred = rf_model.predict(X_test)

print("Random Forest predictions generated successfully!")
print("Number of predictions:", len(rf_pred))
# Out:
# Random Forest predictions generated successfully!
# Number of predictions: 78

# %%
rf_accuracy = accuracy_score(y_test, rf_pred)

print("Logistic Regression Accuracy: {:.2f}%".format(accuracy * 100))
print("Random Forest Accuracy: {:.2f}%".format(rf_accuracy * 100))
# Out:
# Logistic Regression Accuracy: 92.31%
# Random Forest Accuracy: 93.59%

# %%
print("Random Forest Classification Report:\n")
print(classification_report(y_test, rf_pred))
# Out:
# Random Forest Classification Report:
#
#               precision    recall  f1-score   support
#
#            1       0.94      1.00      0.97        16
#            2       1.00      0.87      0.93        15
#            3       1.00      1.00      1.00        16
#            4       0.93      0.88      0.90        16
#            5       0.82      0.93      0.88        15
#
#     accuracy                           0.94        78
#    macro avg       0.94      0.93      0.94        78
# weighted avg       0.94      0.94      0.94        78

# %%
models = ["Logistic Regression", "Random Forest"]
accuracies = [accuracy * 100, rf_accuracy * 100]

plt.figure(figsize=(8, 5))

bars = plt.bar(models, accuracies)

plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy (%)")
plt.ylim(0, 100)

for bar, value in zip(bars, accuracies):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value + 1,
        f"{value:.2f}%",
        ha="center"
    )

plt.tight_layout()
plt.show()

# %%
rf_cm = confusion_matrix(y_test, rf_pred)

print("Random Forest Confusion Matrix:")
print(rf_cm)
# Out:
# Random Forest Confusion Matrix:
# [[16  0  0  0  0]
#  [ 0 13  0  0  2]
#  [ 0  0 16  0  0]
#  [ 1  0  0 14  1]
#  [ 0  0  0  1 14]]

# %%
plt.figure(figsize=(7, 6))

sns.heatmap(
    rf_cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=rf_model.classes_,
    yticklabels=rf_model.classes_
)

plt.title("Confusion Matrix - Random Forest")
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")

plt.tight_layout()
plt.show()

# %%
rf_importance = pd.DataFrame({
    "Gene": X.columns,
    "Importance": rf_model.feature_importances_
})

rf_importance = rf_importance.sort_values(
    "Importance",
    ascending=False
)

print("Top 10 most important genes:")
display(rf_importance.head(10))
# Out:
# Top 10 most important genes:
#        Gene  Importance
# 24  gene_30    0.078824
# 22  gene_28    0.069694
# 12  gene_18    0.065760
# 38  gene_44    0.063459
# 40  gene_46    0.060185
# 39  gene_45    0.057126
# 2    gene_3    0.051300
# 30  gene_36    0.047875
# 20  gene_26    0.046761
# 33  gene_39    0.040161

# %%
top_genes = rf_importance.head(10).sort_values(
    "Importance",
    ascending=True
)

plt.figure(figsize=(8, 6))

plt.barh(
    top_genes["Gene"],
    top_genes["Importance"]
)

plt.xlabel("Feature Importance")
plt.ylabel("Gene")
plt.title("Top 10 Gene Features - Random Forest")

plt.tight_layout()
plt.show()

# %%
if rf_accuracy > accuracy:
    final_model = rf_model
    final_model_name = "Random Forest"
else:
    final_model = model
    final_model_name = "Logistic Regression"

print("Selected final model:", final_model_name)
print("Final test accuracy: {:.2f}%".format(
    max(rf_accuracy, accuracy) * 100
))
# Out:
# Selected final model: Random Forest
# Final test accuracy: 93.59%

# %%
joblib.dump(final_model, "dna_cancer_random_forest.pkl")

print("Final model saved successfully!")
print("File: dna_cancer_random_forest.pkl")
# Out:
# Final model saved successfully!
# File: dna_cancer_random_forest.pkl

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300,
#                        random_state=42)

# %%
joblib.dump(
    list(X.columns),
    "dna_gene_features.pkl"
)

print("Gene feature list saved successfully!")
print("Number of features saved:", len(X.columns))
# Out:
# Gene feature list saved successfully!
# Number of features saved: 44

# %%
loaded_model = joblib.load("dna_cancer_random_forest.pkl")

loaded_predictions = loaded_model.predict(X_test)

loaded_accuracy = accuracy_score(
    y_test,
    loaded_predictions
)

print("Saved model loaded successfully!")
print("Loaded model accuracy: {:.2f}%".format(
    loaded_accuracy * 100
))
# Out:
# Saved model loaded successfully!
# Loaded model accuracy: 93.59%

# %%
import joblib
import pandas as pd
import numpy as np

# Load saved model and feature names
saved_model = joblib.load("dna_cancer_random_forest.pkl")
saved_features = joblib.load("dna_gene_features.pkl")

def predict_cancer_class(sample):
    """
    Predict cancer class from one DNA sample.

    sample must contain all 44 gene features.
    """

    # Convert input into DataFrame
    sample_df = pd.DataFrame([sample])

    # Check required features
    missing_features = set(saved_features) - set(sample_df.columns)

    if missing_features:
        raise ValueError(
            f"Missing gene features: {sorted(missing_features)}"
        )

    # Keep features in exactly the same order used during training
    sample_df = sample_df[saved_features]

    # Make prediction
    prediction = saved_model.predict(sample_df)[0]

    # Get prediction probabilities
    probabilities = saved_model.predict_proba(sample_df)[0]

    probability_df = pd.DataFrame({
        "Class": saved_model.classes_,
        "Probability": probabilities
    }).sort_values(
        "Probability",
        ascending=False
    )

    return prediction, probability_df

# %%
sample = X.iloc[0].to_dict()

actual_class = y.iloc[0]

predicted_class, probabilities = predict_cancer_class(sample)

print("Actual Class:", actual_class)
print("Predicted Class:", predicted_class)

print("\nPrediction Probabilities:")
display(probabilities)
# Out:
# Actual Class: 1
# Predicted Class: 1
#
# Prediction Probabilities:
#    Class  Probability
# 0      1     0.953333
# 4      5     0.016667
# 1      2     0.013333
# 3      4     0.010000
# 2      3     0.006667

# %%
all_predictions = saved_model.predict(X)

print("Total samples tested:", len(X))
print(
    "Correct predictions:",
    np.sum(all_predictions == y)
)
print(
    "Overall dataset accuracy:",
    f"{accuracy_score(y, all_predictions) * 100:.2f}%"
)
# Out:
# Total samples tested: 390
# Correct predictions: 385
# Overall dataset accuracy: 98.72%
